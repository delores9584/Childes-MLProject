# %%
from sklearn.model_selection import train_test_split
from keras.preprocessing.text import Tokenizer, text_to_word_sequence
from keras.preprocessing.sequence import pad_sequences
from keras.utils import to_categorical
from keras.layers import Embedding, Flatten, Dense
from keras.models import Sequential

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import keras
from keras import models, layers, regularizers
# Out:
# Using TensorFlow backend.

# %%
data = pd.read_csv("Gillam_fin.csv").dropna()
data = data.drop("Unnamed: 0", axis = 1)
pd.DataFrame.head(data)
# Out:
#         id  transcript_id                                              gloss  \
# 0  3772732           9573             and she asked um where do you wanna go
# 1  3772777           9573            and the kids I guess answered Mcdonalds
# 2  3772812           9573                      and so they went to Mcdonalds
# 3  3772852           9573                 and Lisa couldn't make up her mind
# 4  3772884           9573  and um she was deciding between a Big_Mac or a...
#
#                                       part_of_speech  Impaired  Age  Gender
# 0            coord pro0sub v adv0int mod pro0per v v         1   10       0
# 1                           coord det0art n v n0prop         1   10       0
# 2                     coord co pro0sub v prep n0prop         1   10       0
# 3                 coord n0prop mod v prep det0poss n         1   10       0
# 4  coord pro0sub aux part prep det0art n0prop coo...         1   10       0

# %%
# Split train, val, test
train, test = train_test_split(data, test_size=0.15, random_state=1234, shuffle = True)

# Process POS tags as X variable
str_train = list(train["part_of_speech"])
str_test = list(test["part_of_speech"])

Imp_train = train["Impaired"]
Imp_test = test["Impaired"]

Age_train = train["Age"]
Age_test = test["Age"]

# %%
# Vectorize tags
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer(encoding = 'utf-8', ngram_range=(2,3), max_features = 500)
X_train = vectorizer.fit_transform(str_train)
X_test = vectorizer.transform(str_test)
pos_vocab = vectorizer.vocabulary_

# %% [markdown]
# ## Preparing model lists

# %%
from sklearn.metrics import accuracy_score, mean_squared_error, roc_auc_score
from sklearn.model_selection import KFold, cross_val_score, StratifiedKFold
from sklearn.naive_bayes import MultinomialNB
from sklearn.svm import LinearSVC
from sklearn.linear_model import LogisticRegression, Ridge, Lasso, ElasticNet

# Create a list of models
models = []
models_mse = []

err_lst = ['neg_mean_squared_error', 'roc_auc']

def get_err(model, X, y):
    """
    Define a function that returns MSE and AUC
    """
    mse = np.mean(-cross_val_score(model, X, y, scoring=err_lst[0], cv = 5))
    return mse

# %% [markdown]
# # Analysis 1: Impaired ~ POS vectors

# %%
## Logistic Regression
# Training
mse_lst = []
C_lst = np.arange(0.001, 0.01, 0.001)
for c in C_lst:
    LR = LogisticRegression(
        multi_class = "multinomial",
        solver = 'newton-cg',
        penalty = 'l2',
        C = c)
    LR.fit(X_train, Age_train)
    mse = np.mean(-cross_val_score(LR, X_train, Age_train, cv=KFold(5), scoring=err_lst[0]))
    mse_lst.append(mse)
        
mse = min(mse_lst)
opt_C = C_lst[np.argmin(mse_lst)]
print("Best hyperparameter for Logistic Regression penalty is {}".format([{'C' : opt_C}]))

# Evaluation
LR_opt = LogisticRegression(
        multi_class = "multinomial",
        solver = 'newton-cg',
        penalty = 'l2',
        C = opt_C)
LR_opt.fit(X_train, Age_train)

print("MSE: {:.6f}".format(mse))

models.append(LR_opt)
models_mse.append(mse)
# Out:
# Best hyperparameter for Logistic Regression penalty is [{'C': 0.001}]
# MSE: 2.910074

# %%
## Naive-Bayes
# Training
NB = MultinomialNB()
NB.fit(X_train, Age_train)

# Evaluation
mse = get_err(NB, X_train, Age_train)

print("MSE: {:.6f}".format(mse))

models.append(NB)
models_mse.append(mse)
# Out:
# MSE: 3.565425

# %%
## SVM Classifier
# Training
SVC = LinearSVC(multi_class = "ovr")
SVC.fit(X_train, Age_train)

# Evaluation
mse = get_err(SVC, X_train, Age_train)

print("MSE: {:.6f}".format(mse))

models.append(SVC)
models_mse.append(mse)
# Out:
# MSE: 4.009793

# %%
##### Ridge
# Tuning
alphas = np.arange(7,8.5,.1)
mse_lst = []
for a in alphas:
    ridge = Ridge(alpha = a, solver = 'auto')
    ridge.fit(X_train, Age_train)
    mse = np.mean(-cross_val_score(ridge, X_train, Age_train, cv=KFold(5), scoring=err_lst[0]))
    mse_lst.append(mse)
        
mse = min(mse_lst)
opt_a = alphas[np.argmin(mse_lst)]
print("Best hyperparameter for Ridge penalty is {}".format([{'alpha' : opt_a}]))

# Evaluation
ridge_opt = Ridge(alpha = opt_a, solver = 'auto')
mse = get_err(ridge_opt, X_train, Age_train)

print("MSE: {:.6f}".format(mse))

models.append(ridge_opt)
models_mse.append(mse)
# Out:
# Best hyperparameter for Ridge penalty is [{'alpha': 8.399999999999995}]
# MSE: 2.759956

# %%
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from sklearn.ensemble import RandomForestClassifier

## Random Forest

rf = RandomForestClassifier(
        n_estimators= 500,
        random_state= 1,
        criterion= 'gini',
        max_depth= 3,
        min_weight_fraction_leaf= 0.1,
        bootstrap= True)
rf.fit(X_train,Age_train)
mse = get_err(rf, X_train, Age_train)
print("MSE: {:.6f}".format(mse))

models.append(rf)
models_mse.append(mse)
# Out:
# MSE: 2.911650

# %%
# Models Summary
models_col = ['Logistic Regression', 'Naive-Bayes', "LinearSVC",
              'Ridge', 'Random Forest']
models_report = pd.DataFrame([models_col, models_mse]).T
models_report = models_report.rename({0 : "Models", 1 : "Error Rates"}, axis = 1)
models_report = models_report.sort_values("Error Rates")

# %%
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.serif'] = ['Times New Roman'] + plt.rcParams['font.serif']
plt.rcParams['axes.titlepad'] = 20

plt.figure(figsize = (10,6), dpi = 300)
plt.bar(models_report["Models"], models_report["Error Rates"])
plt.xticks(rotation = 30)
plt.ylabel("Error Rates", fontsize = 14)
plt.title('Error Rates for Models', fontsize = 20)
# Out:
# Text(0.5, 1.0, 'Error Rates for Models')

# %%
from skater.model import InMemoryModel
from skater.core.explanations import Interpretation

best_model = models[3].fit(X_train, Age_train)

# # calculate the feature importance
model = InMemoryModel(best_model.predict, examples = X_train.toarray())
interpreter = Interpretation(X_train.toarray())
importance = interpreter.feature_importance.feature_importance(model)
# Out:
# [82/500] features ███----------------- Time elapsed: 76 seconds
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-803a89868a6f> in <module>
#       7 model = InMemoryModel(best_model.predict, examples = X_train.toarray())
#       8 interpreter = Interpretation(X_train.toarray())
# ----> 9 importance = interpreter.feature_importance.feature_importance(model)
#
# ~/anaconda3/lib/python3.7/site-packages/skater/core/global_interpretation/feature_importance.py in feature_importance(self, model_instance, ascending, filter_classes, progressbar)
#      88             else:
#      89                 samples = self.data_set.generate_column_sample(feature_id, n_samples=n, method='random-choice')
# ---> 90             copy_of_data_set[feature_id] = samples
#      91
#      92             # predict based on perturbed values
#
# ~/anaconda3/lib/python3.7/site-packages/skater/data/datamanager.py in __setitem__(self, key, newval)
#     262         else:
#     263             raise ValueError("Can't set item for data of type {}".format(self.data_type))
# --> 264         self.sync_metadata()
#     265
#     266
#
# ~/anaconda3/lib/python3.7/site-packages/skater/data/datamanager.py in sync_metadata(self)
#     160         self.data_info[self._dim] = self._calculate_n_rows()
#     161         self.data_info[self._dtypes] = self._calculate_dtypes()
# --> 162         self.data_info[self._feature_info] = self._calculate_feature_info()
#     163
#     164
#
# ~/anaconda3/lib/python3.7/site-packages/skater/data/datamanager.py in _calculate_feature_info(self)
#     184             feature_info[feature] = {
#     185                 'type': self.dtypes.loc[feature],
# --> 186                 'unique': len(np.unique(x)),
#     187                 'numeric': is_numeric
#     188             }
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/lib/arraysetops.py in unique(ar, return_index, return_inverse, return_counts, axis)
#     231     ar = np.asanyarray(ar)
#     232     if axis is None:
# --> 233         ret = _unique1d(ar, return_index, return_inverse, return_counts)
#     234         return _unpack_tuple(ret)
#     235
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/lib/arraysetops.py in _unique1d(ar, return_index, return_inverse, return_counts)
#     279         aux = ar[perm]
#     280     else:
# --> 281         ar.sort()
#     282         aux = ar
#     283     mask = np.empty(aux.shape, dtype=np.bool_)
#
# KeyboardInterrupt:

# %%
feature_idx = list(importance[-50:].index)
features = []
for idx in feature_idx:
    features.append(list(pos_vocab.keys())[list(pos_vocab.values()).index(idx)])

# %%
plt.figure(figsize=(8,12), dpi = 500)
plt.scatter(importance[-50:], np.arange(50))
plt.yticks(np.arange(50), features)
plt.title('Feature Importances', fontsize = 15)
plt.xlabel('Feature Importance')
plt.ylabel('Features')
# plt.show()
plt.savefig('plot.png')

# %%
from pycebox.ice import ice, ice_plot
# Because ridge has no attribute of predict_proba, I used LogisticRegression with penalty 'l2' (ridge Regression) instead. 
## In this case, penalty = 'l2', c = 1/alpha

ridge1 = LogisticRegression(C = 1/opt_a, penalty = 'l2', solver = 'sag')
ridge1 = ridge1.fit(X_train, Age_train)
pred_func = lambda x: ridge1.predict_proba(x)[:,0]

X_train_df = pd.DataFrame(X_train.todense())
X_train_df

feat_idx = list(importance[-5:].keys())
for i in feat_idx:
    ice_df = ice(X_train_df, i, pred_func)
    ice_plot(ice_df, color='gray', linewidth=0.2, alpha=0.8, 
             centered = True, plot_pdp=True)
#     _ = plt.title(i, fontsize = 15)

# %%
importance[-5:].keys()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-435fe87c6995> in <module>
# ----> 1 importance[-5:].keys()
#
# NameError: name 'importance' is not defined
